# %% [markdown]
# # IMPORTS
# Importa as bibliotecas necessárias:
# - `tensorflow` e `keras` para construir e treinar o modelo.
# - `matplotlib.pyplot` para visualizar gráficos e imagens.
# - `os`, `zipfile` e `pathlib` para manipulação de arquivos e diretórios.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import os, zipfile, pathlib

print("TensorFlow versão:", tf.__version__)
# Out:
# TensorFlow versão: 2.19.0

# %% [markdown]
# # DOWNLOAD DO DATASET
# - Define o diretório e o nome do arquivo ZIP do dataset Cats and Dogs.
# - Baixa o dataset se ainda não existir.
# - Extrai o conteúdo do ZIP para o diretório especificado.

# %%
DATASET_DIR = "cats_and_dogs_manual"
ZIP_FILENAME = "kagglecatsanddogs_5340.zip"
DOWNLOAD_URL = "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip"

if not os.path.exists(ZIP_FILENAME):
    print("Baixando dataset")
    # !wget -O "{ZIP_FILENAME}" "{DOWNLOAD_URL}"

if not os.path.exists(DATASET_DIR):
    print("Extraindo o arquivo ZIP...")
    with zipfile.ZipFile(ZIP_FILENAME, "r") as zip_ref:
        zip_ref.extractall(DATASET_DIR)

print("Download e extração concluídos!")
# Out:
# Download e extração concluídos!

# %% [markdown]
# # CONFIGURAÇÕES
# - Define tamanho das imagens (IMG_SIZE = 224).
# - Define tamanho do batch (BATCH_SIZE = 32) e seed para aleatoriedade.
# - Define o caminho para as imagens (`data_path`).

# %%
IMG_SIZE = 224
BATCH_SIZE = 32
SEED = 123

data_path = pathlib.Path(os.path.join(DATASET_DIR, "PetImages"))

# %% [markdown]
# # FILTRAR IMAGENS VÁLIDAS
# - Cria lista de todos os arquivos de imagem.
# - Tenta abrir cada imagem com TensorFlow:
#     - Se a imagem estiver corrompida, ignora.
# - Cria lista de labels:
#     - 0 = Gato
#     - 1 = Cachorro

# %%
all_image_paths = list(data_path.glob("*/*.jpg")) + list(data_path.glob("*/*.png"))

valid_image_paths = []
for p in all_image_paths:
    try:
        img = tf.io.read_file(str(p))
        img = tf.io.decode_jpeg(img, channels=3)
        valid_image_paths.append(str(p))
    except:
        print(f"Ignorado arquivo corrompido: {p}")

print(f"Total de imagens válidas: {len(valid_image_paths)}")

labels = [0 if "Cat" in p else 1 for p in valid_image_paths]
# Out:
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/296.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/2905.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/2494.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/663.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/573.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8364.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/2479.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/565.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/7311.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5547.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6032.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8693.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4086.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10733.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8521.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/3885.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/1356.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/522.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/414.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9145.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11560.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/3038.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6855.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6503.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9967.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/3155.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9367.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6305.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4257.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8126.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5263.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/7743.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/1168.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11590.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10705.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/543.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11166.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4640.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6500.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9026.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10173.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10969.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9643.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6213.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5618.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5790.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6430.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4654.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/719.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11233.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4924.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8557.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9414.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/2353.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9556.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10353.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9500.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8641.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9961.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/3546.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5104.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/6555.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/12289.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10351.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10863.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/12102.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4301.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/7739.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5243.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10972.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/561.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4203.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/7652.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/1259.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/7128.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9851.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/3927.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/2915.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9640.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/1017.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/2317.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10726.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/12114.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8715.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10907.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/3320.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/50.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11702.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8194.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/1884.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11692.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10637.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/9043.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10678.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/1900.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/8563.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/4134.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5955.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/10383.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/7718.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11253.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/11912.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Dog/5730.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6029.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/2742.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4874.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/12269.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/1267.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6491.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4000.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/11095.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/12080.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/5077.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6486.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4821.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/1936.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/910.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/5614.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/11864.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/10874.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/8958.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/3710.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/8183.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6435.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/23.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/11729.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4334.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/10404.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4629.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4351.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/12235.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/11086.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6376.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/2569.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/9328.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/3649.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/3153.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/5819.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/7845.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4929.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6980.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/8295.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/3197.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4750.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4293.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/391.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6768.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/1937.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/3161.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/7502.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6900.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/2189.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/11083.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/7642.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/11397.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/666.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/8415.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/9619.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/3967.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/1386.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/9361.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/4322.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/7647.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/8553.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/8832.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/9208.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/9100.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/7003.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/1151.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/5370.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/1757.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/6906.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/10073.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/445.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/2021.jpg
# Ignorado arquivo corrompido: cats_and_dogs_manual/PetImages/Cat/1914.jpg
# Total de imagens válidas: 24824

# %% [markdown]
# # CRIAR DATASET TF
# - Converte a lista de caminhos e labels em um `tf.data.Dataset`.
# - Função `load_and_preprocess`:
#     - Lê a imagem.
#     - Decodifica JPEG.
#     - Redimensiona para IMG_SIZE.
#     - Normaliza valores de pixels para [0,1].
# - Aplica a função ao dataset com `map`.

# %%
dataset = tf.data.Dataset.from_tensor_slices((valid_image_paths, labels))

def load_and_preprocess(path, label):
    image = tf.io.read_file(path)
    image = tf.io.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

dataset = dataset.map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# # SHUFFLE E SPLIT 70/15/15
# - Embaralha o dataset.
# - Calcula tamanhos de treino, validação e teste.
# - Divide o dataset em:
#     - ds_train (70%)
#     - ds_val (15%)
#     - ds_test (15%)

# %%
dataset = dataset.shuffle(1000, seed=SEED, reshuffle_each_iteration=False)
dataset_size = len(valid_image_paths)

train_size = int(0.7 * dataset_size)
val_size   = int(0.15 * dataset_size)
test_size  = dataset_size - train_size - val_size

ds_train = dataset.take(train_size).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_val   = dataset.skip(train_size).take(val_size).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
ds_test  = dataset.skip(train_size + val_size).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("Tamanhos (treino / validação / teste):", train_size, val_size, test_size)
# Out:
# Tamanhos (treino / validação / teste): 17376 3723 3725

# %% [markdown]
# # MODELO TRANSFER LEARNING (MobileNetV2)
# - Usa MobileNetV2 pré-treinado como base.
# - Congela suas camadas para não treinar novamente.
# - Adiciona camadas:
#     - GlobalAveragePooling2D
#     - Dense 128 + ReLU
#     - Dropout 0.3
#     - Dense 1 + Sigmoid
# - Compila modelo com Adam, loss binária e métrica de acurácia.

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights="imagenet"
)
base_model.trainable = False  # congela camadas

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,081 (9.24 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# # TREINAMENTO
# - Treina o modelo com ds_train e validação em ds_val.
# - Número de épocas: 5.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_val,
    epochs=5
)
# Out:
# Epoch 1/5
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 911s 2s/step - accuracy: 0.9772 - loss: 0.0649 - val_accuracy: 0.9992 - val_loss: 0.0030
# Epoch 2/5
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 907s 2s/step - accuracy: 0.9812 - loss: 0.0503 - val_accuracy: 0.9987 - val_loss: 0.0034
# Epoch 3/5
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 791s 1s/step - accuracy: 0.9860 - loss: 0.0377 - val_accuracy: 0.9987 - val_loss: 0.0038
# Epoch 4/5
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 797s 1s/step - accuracy: 0.9882 - loss: 0.0304 - val_accuracy: 0.9987 - val_loss: 0.0046
# Epoch 5/5
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 853s 2s/step - accuracy: 0.9896 - loss: 0.0265 - val_accuracy: 0.9987 - val_loss: 0.0045

# %% [markdown]
# # GRÁFICO DE ACURÁCIA
# - Plota a acurácia de treino e validação ao longo das épocas.

# %%
plt.plot(history.history["accuracy"], label="Treino")
plt.plot(history.history["val_accuracy"], label="Validação")
plt.legend()
plt.title("Acurácia do Modelo")
plt.show()

# %% [markdown]
# # AVALIAÇÃO NO CONJUNTO DE TESTE
# - Avalia modelo em ds_test.
# - Exibe acurácia final do modelo no conjunto de teste.

# %%
test_loss, test_acc = model.evaluate(ds_test)
print(f"Acurácia no conjunto de teste: {test_acc:.4f}")
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.9995 - loss: 0.0017
# Acurácia no conjunto de teste: 0.9987

# %% [markdown]
# # VISUALIZAÇÃO DE PREDIÇÕES
# - Pega um batch do conjunto de teste.
# - Faz predições.
# - Exibe até 5 imagens com:
#     - Label real (Gato/Cachorro)
#     - Predição do modelo (Gato/Cachorro)

# %%
for images, labels in ds_test.take(1):
    preds = model.predict(images)
    for i in range(min(5, images.shape[0])):
        plt.imshow(images[i].numpy())
        plt.title(f"Real: {'Cachorro' if labels[i].numpy()==1 else 'Gato'} | Prev: {'Cachorro' if preds[i]>0.5 else 'Gato'}")
        plt.axis("off")
        plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
